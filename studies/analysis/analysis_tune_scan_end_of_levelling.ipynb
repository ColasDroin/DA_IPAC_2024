# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
import analysis_functions

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Plot tune scan

# %%
# Define study
STUDY_NAME = "tune_scan_end_of_levelling"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                                              name base collider  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0               base_collider
#
#                                               normalized amplitude in xy-plane  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0                                        4.0
#
#                                                   qx      qy   dqx   dqy  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0           62.305  60.309  15.0  15.0
#
#                                               i_bunch_b1  i_bunch_b2  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0                150.0       147.0
#
#                                               i_oct_b1  i_oct_b2  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0              -60.0     -60.0
#
#                                               num_particles_per_bunch  \
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0                      2.200000e+11
#
#                                               crossing_angle
# beam  num_particles_per_bunch crossing_angle
# lhcb1 2.200000e+11            250.0                    250.0

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305
# qy
# 60.309     4.0

# %%
# Replace NaNs above the upper diagonal with 8
for qx in df_to_plot.columns:
    for qy in df_to_plot.index:
        if qy >= qx - 2 + 0.004:
            if pd.isna(df_to_plot.loc[qy, qx]):
                df_to_plot.loc[qy, qx] = 8

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    f'{STUDY_NAME}_{COLLIDER}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=0.15,
    bety=0.15,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)
# ! Verified
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
#       3 conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
# ----> 4 analysis_functions.plot_heatmap(
#       5     df_to_plot,
#       6     f'{STUDY_NAME}_{COLLIDER}',
#       7     link=None,
#       8     plot_contours=True,
#       9     conf_mad=conf_mad,
#      10     conf_collider=conf_collider,
#      11     type_crossing="flathv",
#      12     betx=0.15,
#      13     bety=0.15,
#      14     Nb=True,
#      15     green_contour=6.,
#      16     extended_diagonal=False,
#      17     vmin=4.,
#      18     vmax=8.0,
#      19     CC = True,
#      20 )
#      21 # ! Verified
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/studies/analysis/analysis_functions.py:418, in plot_heatmap(df_to_plot, study_name, link, plot_contours, conf_mad, conf_collider, type_crossing, betx, bety, Nb, levelling, CC, xlabel, ylabel, symmetric, mask_lower_triangle, mask_upper_triangle, plot_diagonal_lines, xaxis_ticks_on_top, title, add_vline, display_intensity, PU, display_xing, display_tune, ignore_lumi_1_5, vmin, vmax, extended_diagonal, green_contour)
#     416 # Plot contours if requested
#     417 if plot_contours:
# --> 418     CSS = ax.contour(
#     419         np.arange(0.5, data_array.shape[1]),
#     420         np.arange(0.5, data_array.shape[0]),
#     421         mx,
#     422         colors="black",
#     423         levels=list(np.arange(3, green_contour, 0.5))
#     424         + list(np.arange(green_contour + 0.5, 10, 0.5)),
#     425         linewidths=0.2,
#     426     )
#     427     ax.clabel(CSS, inline=True, fontsize=6)
#     428     CS2 = ax.contour(
#     429         np.arange(0.5, data_array.shape[1]),
#     430         np.arange(0.5, data_array.shape[0]),
#    (...)
#     434         linewidths=1,
#     435     )
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6520, in Axes.contour(self, *args, **kwargs)
#    6511 """
#    6512 Plot contour lines.
#    6513
#    (...)
#    6517 %(contour_doc)s
#    6518 """
#    6519 kwargs['filled'] = False
# -> 6520 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6521 self._request_autoscale_view()
#    6522 return contours
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File /afs/cern.ch/work/c/cdroin/private/DA_HL_2024/.venv/lib/python3.10/site-packages/matplotlib/contour.py:1591, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
# -> 1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#    1593 Ny, Nx = z.shape
#    1595 if x.ndim != y.ndim:
#
# TypeError: Input z must be at least a (2, 2) shaped array, but has shape (1, 1)

# %% [markdown]
# ### Previous tune scan

# %%
# Define study
STUDY_NAME_alt = "tune_scan_end_of_levelling"
COLLIDER_alt = "base_collider"
PARQUET_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_IPAC_2024/studies/scans/tune_scan_end_of_levelling/da.parquet"
CONF_MAD_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_IPAC_2024/studies/scans/tune_scan_end_of_levelling/base_collider/config.yaml"
CONF_COLLIDER_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_IPAC_2024/studies/scans/tune_scan_end_of_levelling/base_collider/xtrack_0016/config.yaml"

# Load dataframe
df_alt = pd.read_parquet(PARQUET_PATH_alt)

# Round all numbers to 3 decimals
df_alt = df_alt.round(3)

# Keep only relevant collider
df_alt = df_alt.reset_index(level=1)
df_alt = df_alt[df_alt["name base collider"] == COLLIDER_alt]

df_alt
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.309      base_collider                             4.000
#              60.310      base_collider                             4.125
#              60.311      base_collider                             4.094
#              60.312      base_collider                             4.000
#              60.313      base_collider                             4.062
# ...                                ...                               ...
#       62.323 60.328      base_collider                             4.000
#              60.329      base_collider                             4.000
#       62.324 60.328      base_collider                             4.000
#              60.329      base_collider                             4.000
#       62.325 60.329      base_collider                             4.000
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.309  62.305  60.309  15.0  15.0       150.0       147.0
#              60.310  62.305  60.310  15.0  15.0       150.0       147.0
#              60.311  62.305  60.311  15.0  15.0       150.0       147.0
#              60.312  62.305  60.312  15.0  15.0       150.0       147.0
#              60.313  62.305  60.313  15.0  15.0       150.0       147.0
# ...                     ...     ...   ...   ...         ...         ...
#       62.323 60.328  62.323  60.328  15.0  15.0       150.0       147.0
#              60.329  62.323  60.329  15.0  15.0       150.0       147.0
#       62.324 60.328  62.324  60.328  15.0  15.0       150.0       147.0
#              60.329  62.324  60.329  15.0  15.0       150.0       147.0
#       62.325 60.329  62.325  60.329  15.0  15.0       150.0       147.0
#
#                      num_particles_per_bunch  crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.309             2.200000e+11           250.0
#              60.310             2.200000e+11           250.0
#              60.311             2.200000e+11           250.0
#              60.312             2.200000e+11           250.0
#              60.313             2.200000e+11           250.0
# ...                                      ...             ...
#       62.323 60.328             2.200000e+11           250.0
#              60.329             2.200000e+11           250.0
#       62.324 60.328             2.200000e+11           250.0
#              60.329             2.200000e+11           250.0
#       62.325 60.329             2.200000e+11           250.0
#
# [231 rows x 10 columns]

# %%
# Reshape for plotting
df_to_plot_alt = df_alt.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot_alt
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.309   4.000     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310   4.125   4.000     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311   4.094   4.000   5.375     NaN     NaN     NaN     NaN     NaN
# 60.312   4.000   4.375   5.688   5.562     NaN     NaN     NaN     NaN
# 60.313   4.062   4.125   5.406   5.812   5.688     NaN     NaN     NaN
# 60.314   4.062   4.125   5.812   5.875   5.656   5.938     NaN     NaN
# 60.315   4.094   4.062   5.625   5.500   5.438   5.469   5.656     NaN
# 60.316   4.219   4.125   5.219   5.625   5.938   6.094   5.469   5.469
# 60.317   4.062   5.312   5.594   5.625   5.688   5.500   5.688   5.719
# 60.318   4.094   5.156   5.656   5.500   5.625   5.562   5.719   5.375
# 60.319   4.469   5.031   5.062   5.375   5.656   5.688   5.562   5.688
# 60.320   4.125   5.156   4.875   5.375   5.375   5.656   5.719   5.469
# 60.321   4.562   4.938   4.969   5.312   5.031   5.188   5.125   5.531
# 60.322   4.469   4.750   4.219   4.844   5.000   4.750   4.906   5.000
# 60.323   4.094   4.406   4.031   4.000   4.125   4.375   4.625   4.031
# 60.324   4.031   4.000   4.062   4.031   4.125   4.125   4.000   4.094
# 60.325   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.326   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.327   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.328   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
# 60.329   4.000   4.000   4.000   4.000   4.000   4.000   4.000   4.000
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.309     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.317   5.969     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.318   5.781   6.562  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.319   6.125   6.094  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 60.320   5.656   5.719  ...   6.250     NaN     NaN     NaN     NaN     NaN
# 60.321   5.344   5.406  ...   5.625   5.781     NaN     NaN     NaN     NaN
# 60.322   5.000   4.906  ...   4.906   5.125   5.188     NaN     NaN     NaN
# 60.323   4.719   4.656  ...   4.500   4.719   4.750   4.656     NaN     NaN
# 60.324   4.031   4.094  ...   4.125   4.188   4.031   4.031   4.062     NaN
# 60.325   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000     4.0
# 60.326   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000     4.0
# 60.327   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000     4.0
# 60.328   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000     4.0
# 60.329   4.000   4.000  ...   4.000   4.000   4.000   4.000   4.000     4.0
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.309     NaN     NaN     NaN     NaN
# 60.310     NaN     NaN     NaN     NaN
# 60.311     NaN     NaN     NaN     NaN
# 60.312     NaN     NaN     NaN     NaN
# 60.313     NaN     NaN     NaN     NaN
# 60.314     NaN     NaN     NaN     NaN
# 60.315     NaN     NaN     NaN     NaN
# 60.316     NaN     NaN     NaN     NaN
# 60.317     NaN     NaN     NaN     NaN
# 60.318     NaN     NaN     NaN     NaN
# 60.319     NaN     NaN     NaN     NaN
# 60.320     NaN     NaN     NaN     NaN
# 60.321     NaN     NaN     NaN     NaN
# 60.322     NaN     NaN     NaN     NaN
# 60.323     NaN     NaN     NaN     NaN
# 60.324     NaN     NaN     NaN     NaN
# 60.325     NaN     NaN     NaN     NaN
# 60.326     4.0     NaN     NaN     NaN
# 60.327     4.0     4.0     NaN     NaN
# 60.328     4.0     4.0     4.0     NaN
# 60.329     4.0     4.0     4.0     4.0
#
# [21 rows x 21 columns]

# %%
# Replace NaNs above the upper diagonal with 8
for qx in df_to_plot_alt.columns:
    for qy in df_to_plot_alt.index:
        if qy >= qx - 2 + 0.004:
            if pd.isna(df_to_plot_alt.loc[qy, qx]):
                df_to_plot_alt.loc[qy, qx] = 8

# %%
# Load configuration files
conf_mad_alt = analysis_functions.load_config(CONF_MAD_PATH_alt)['config_mad']
conf_collider_alt = analysis_functions.load_config(CONF_COLLIDER_PATH_alt)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot_alt,
    f'{STUDY_NAME_alt}_{COLLIDER_alt}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad_alt,
    conf_collider=conf_collider_alt,
    type_crossing="flathv",
    betx=0.15,
    bety=0.15,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)

# %%
df_diff = df_to_plot_alt - df_to_plot

# %%
# Load configuration files
conf_mad_alt = analysis_functions.load_config(CONF_MAD_PATH_alt)['config_mad']
conf_collider_alt = analysis_functions.load_config(CONF_COLLIDER_PATH_alt)["config_collider"]
analysis_functions.plot_heatmap(
    df_diff,
    f'{STUDY_NAME_alt}_{COLLIDER_alt}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad_alt,
    conf_collider=conf_collider_alt,
    type_crossing="flathv",
    betx=0.15,
    bety=0.15,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=-1.,
    vmax=1.0,
    CC = True,
)

# %% [markdown]
# ### Comparison with coupling

# %%
# Define study
STUDY_NAME_alt = "tune_scan_end_of_levelling_no_coupling"
COLLIDER_alt = "base_collider"
PARQUET_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_HL_2024/studies/scans/tune_scan_end_of_levelling_no_coupling/da.parquet"
CONF_MAD_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_HL_2024/studies/scans/tune_scan_end_of_levelling_no_coupling/base_collider/config.yaml"
CONF_COLLIDER_PATH_alt = f"/afs/cern.ch/work/c/cdroin/private/DA_HL_2024/studies/scans/tune_scan_end_of_levelling_no_coupling/base_collider/xtrack_0016/config.yaml"

# Load dataframe
df_alt = pd.read_parquet(PARQUET_PATH_alt)

# Round all numbers to 3 decimals
df_alt = df_alt.round(3)

# Keep only relevant collider
df_alt = df_alt.reset_index(level=1)
df_alt = df_alt[df_alt["name base collider"] == COLLIDER_alt]

# Reshape for plotting
df_to_plot_alt = df_alt.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")

# Replace NaNs above the upper diagonal with 8
for qx in df_to_plot_alt.columns:
    for qy in df_to_plot_alt.index:
        if qy >= qx - 2 + 0.004:
            if pd.isna(df_to_plot_alt.loc[qy, qx]):
                df_to_plot_alt.loc[qy, qx] = 8
                
df_diff = df_to_plot_alt - df_to_plot

# Load configuration files
conf_mad_alt = analysis_functions.load_config(CONF_MAD_PATH_alt)['config_mad']
conf_collider_alt = analysis_functions.load_config(CONF_COLLIDER_PATH_alt)["config_collider"]
analysis_functions.plot_heatmap(
    df_diff,
    f'{STUDY_NAME_alt}_{COLLIDER_alt}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad_alt,
    conf_collider=conf_collider_alt,
    type_crossing="flathv",
    betx=0.15,
    bety=0.15,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=-1.,
    vmax=1.0,
    CC = True,
)
