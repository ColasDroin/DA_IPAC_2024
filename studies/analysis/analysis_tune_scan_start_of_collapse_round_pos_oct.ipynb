# %% [markdown]
# ### Import modules

# %%
# Standard imports
import pandas as pd
import sys 
import os
import seaborn as sns
import os
import shutil

# Local imports
import analysis_functions

# Apply better style
analysis_functions.apply_heatmap_style()

# %% [markdown]
# ### Plot tune scan

# %%
# Define study
STUDY_NAME = "tune_scan_start_of_collapse_round_pos_oct"
COLLIDER = "base_collider"
PARQUET_PATH = f"../scans/{STUDY_NAME}/da.parquet"
CONF_MAD_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/config.yaml"
CONF_COLLIDER_PATH = f"../scans/{STUDY_NAME}/{COLLIDER}/xtrack_0016/config.yaml"

# Load dataframe
df = pd.read_parquet(f"../scans/{STUDY_NAME}/da.parquet")

# Round all numbers to 3 decimals
df = df.round(3)

# Keep only relevant collider
df = df.reset_index(level=1)
df = df[df["name base collider"] == COLLIDER]

df
# Out:
#                     name base collider  normalized amplitude in xy-plane  \
# beam  qx     qy
# lhcb1 62.305 60.328      base_collider                             6.531
#              60.329      base_collider                             4.938
#       62.306 60.328      base_collider                             6.500
#              60.329      base_collider                             4.938
#       62.307 60.327      base_collider                             7.938
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.969
#       62.308 60.327      base_collider                             7.969
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.906
#       62.309 60.327      base_collider                             7.875
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.969
#       62.310 60.327      base_collider                             7.969
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.938
#       62.311 60.327      base_collider                             7.969
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.938
#       62.312 60.327      base_collider                             7.844
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.906
#       62.313 60.327      base_collider                             7.938
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.906
#       62.314 60.327      base_collider                             7.938
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.938
#       62.315 60.327      base_collider                             7.969
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.938
#       62.316 60.327      base_collider                             7.938
#              60.328      base_collider                             6.562
#              60.329      base_collider                             4.906
#       62.317 60.327      base_collider                             7.875
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.906
#       62.318 60.327      base_collider                             7.969
#              60.328      base_collider                             6.531
#              60.329      base_collider                             4.969
#       62.319 60.327      base_collider                             7.625
#              60.328      base_collider                             6.469
#              60.329      base_collider                             4.906
#       62.320 60.327      base_collider                             7.969
#              60.328      base_collider                             6.562
#              60.329      base_collider                             4.875
#       62.321 60.327      base_collider                             7.906
#              60.328      base_collider                             6.250
#              60.329      base_collider                             5.750
#       62.322 60.327      base_collider                             7.469
#              60.328      base_collider                             6.312
#              60.329      base_collider                             4.844
#       62.323 60.327      base_collider                             7.625
#              60.328      base_collider                             6.469
#              60.329      base_collider                             5.062
#       62.324 60.328      base_collider                             5.250
#              60.329      base_collider                             4.219
#       62.325 60.329      base_collider                             4.844
#
#                          qx      qy   dqx   dqy  i_bunch_b1  i_bunch_b2  \
# beam  qx     qy
# lhcb1 62.305 60.328  62.305  60.328  15.0  15.0       150.0       147.0
#              60.329  62.305  60.329  15.0  15.0       150.0       147.0
#       62.306 60.328  62.306  60.328  15.0  15.0       150.0       147.0
#              60.329  62.306  60.329  15.0  15.0       150.0       147.0
#       62.307 60.327  62.307  60.327  15.0  15.0       150.0       147.0
#              60.328  62.307  60.328  15.0  15.0       150.0       147.0
#              60.329  62.307  60.329  15.0  15.0       150.0       147.0
#       62.308 60.327  62.308  60.327  15.0  15.0       150.0       147.0
#              60.328  62.308  60.328  15.0  15.0       150.0       147.0
#              60.329  62.308  60.329  15.0  15.0       150.0       147.0
#       62.309 60.327  62.309  60.327  15.0  15.0       150.0       147.0
#              60.328  62.309  60.328  15.0  15.0       150.0       147.0
#              60.329  62.309  60.329  15.0  15.0       150.0       147.0
#       62.310 60.327  62.310  60.327  15.0  15.0       150.0       147.0
#              60.328  62.310  60.328  15.0  15.0       150.0       147.0
#              60.329  62.310  60.329  15.0  15.0       150.0       147.0
#       62.311 60.327  62.311  60.327  15.0  15.0       150.0       147.0
#              60.328  62.311  60.328  15.0  15.0       150.0       147.0
#              60.329  62.311  60.329  15.0  15.0       150.0       147.0
#       62.312 60.327  62.312  60.327  15.0  15.0       150.0       147.0
#              60.328  62.312  60.328  15.0  15.0       150.0       147.0
#              60.329  62.312  60.329  15.0  15.0       150.0       147.0
#       62.313 60.327  62.313  60.327  15.0  15.0       150.0       147.0
#              60.328  62.313  60.328  15.0  15.0       150.0       147.0
#              60.329  62.313  60.329  15.0  15.0       150.0       147.0
#       62.314 60.327  62.314  60.327  15.0  15.0       150.0       147.0
#              60.328  62.314  60.328  15.0  15.0       150.0       147.0
#              60.329  62.314  60.329  15.0  15.0       150.0       147.0
#       62.315 60.327  62.315  60.327  15.0  15.0       150.0       147.0
#              60.328  62.315  60.328  15.0  15.0       150.0       147.0
#              60.329  62.315  60.329  15.0  15.0       150.0       147.0
#       62.316 60.327  62.316  60.327  15.0  15.0       150.0       147.0
#              60.328  62.316  60.328  15.0  15.0       150.0       147.0
#              60.329  62.316  60.329  15.0  15.0       150.0       147.0
#       62.317 60.327  62.317  60.327  15.0  15.0       150.0       147.0
#              60.328  62.317  60.328  15.0  15.0       150.0       147.0
#              60.329  62.317  60.329  15.0  15.0       150.0       147.0
#       62.318 60.327  62.318  60.327  15.0  15.0       150.0       147.0
#              60.328  62.318  60.328  15.0  15.0       150.0       147.0
#              60.329  62.318  60.329  15.0  15.0       150.0       147.0
#       62.319 60.327  62.319  60.327  15.0  15.0       150.0       147.0
#              60.328  62.319  60.328  15.0  15.0       150.0       147.0
#              60.329  62.319  60.329  15.0  15.0       150.0       147.0
#       62.320 60.327  62.320  60.327  15.0  15.0       150.0       147.0
#              60.328  62.320  60.328  15.0  15.0       150.0       147.0
#              60.329  62.320  60.329  15.0  15.0       150.0       147.0
#       62.321 60.327  62.321  60.327  15.0  15.0       150.0       147.0
#              60.328  62.321  60.328  15.0  15.0       150.0       147.0
#              60.329  62.321  60.329  15.0  15.0       150.0       147.0
#       62.322 60.327  62.322  60.327  15.0  15.0       150.0       147.0
#              60.328  62.322  60.328  15.0  15.0       150.0       147.0
#              60.329  62.322  60.329  15.0  15.0       150.0       147.0
#       62.323 60.327  62.323  60.327  15.0  15.0       150.0       147.0
#              60.328  62.323  60.328  15.0  15.0       150.0       147.0
#              60.329  62.323  60.329  15.0  15.0       150.0       147.0
#       62.324 60.328  62.324  60.328  15.0  15.0       150.0       147.0
#              60.329  62.324  60.329  15.0  15.0       150.0       147.0
#       62.325 60.329  62.325  60.329  15.0  15.0       150.0       147.0
#
#                      i_oct_b1  i_oct_b2  num_particles_per_bunch  \
# beam  qx     qy
# lhcb1 62.305 60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.306 60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.307 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.308 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.309 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.310 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.311 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.312 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.313 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.314 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.315 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.316 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.317 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.318 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.319 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.320 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.321 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.322 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.323 60.327     300.0     300.0             2.200000e+11
#              60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.324 60.328     300.0     300.0             2.200000e+11
#              60.329     300.0     300.0             2.200000e+11
#       62.325 60.329     300.0     300.0             2.200000e+11
#
#                      crossing_angle
# beam  qx     qy
# lhcb1 62.305 60.328           250.0
#              60.329           250.0
#       62.306 60.328           250.0
#              60.329           250.0
#       62.307 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.308 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.309 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.310 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.311 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.312 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.313 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.314 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.315 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.316 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.317 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.318 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.319 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.320 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.321 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.322 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.323 60.327           250.0
#              60.328           250.0
#              60.329           250.0
#       62.324 60.328           250.0
#              60.329           250.0
#       62.325 60.329           250.0

# %%
# Reshape for plotting
df_to_plot = df.pivot(index="qy", columns="qx", values="normalized amplitude in xy-plane")
df_to_plot
# Out:
# qx      62.305  62.306  62.307  62.308  62.309  62.310  62.311  62.312  \
# qy
# 60.327     NaN     NaN   7.938   7.969   7.875   7.969   7.969   7.844
# 60.328   6.531   6.500   6.531   6.531   6.531   6.531   6.531   6.531
# 60.329   4.938   4.938   4.969   4.906   4.969   4.938   4.938   4.906
#
# qx      62.313  62.314  ...  62.316  62.317  62.318  62.319  62.320  62.321  \
# qy                      ...
# 60.327   7.938   7.938  ...   7.938   7.875   7.969   7.625   7.969   7.906
# 60.328   6.531   6.531  ...   6.562   6.531   6.531   6.469   6.562   6.250
# 60.329   4.906   4.938  ...   4.906   4.906   4.969   4.906   4.875   5.750
#
# qx      62.322  62.323  62.324  62.325
# qy
# 60.327   7.469   7.625     NaN     NaN
# 60.328   6.312   6.469   5.250     NaN
# 60.329   4.844   5.062   4.219   4.844
#
# [3 rows x 21 columns]

# %%
import numpy as np
array_qx = np.round(np.arange(62.305, 62.330, 0.001), decimals=4)
array_qy = np.round(np.arange(60.305, 60.330, 0.001), decimals=4)

# Replace NaNs above the upper diagonal with 8
for qx in array_qx:
    for qy in array_qy:
        if qy >= qx - 2 + 0.004:
            if qx in df_to_plot.columns and qy in df_to_plot.index:
                if pd.isna(df_to_plot.loc[qy, qx]):
                    df_to_plot.loc[qy, qx] = 8
            else:
                df_to_plot.loc[qy, qx] = 8
                
# Sort indices by increasing qy
df_to_plot = df_to_plot.sort_index(ascending=True)

# Sort columns by increasing qx
df_to_plot = df_to_plot.sort_index(axis=1, ascending=True)

# %%
# Load configuration files
conf_mad = analysis_functions.load_config(CONF_MAD_PATH)['config_mad']
conf_collider = analysis_functions.load_config(CONF_COLLIDER_PATH)["config_collider"]
analysis_functions.plot_heatmap(
    df_to_plot,
    f'{STUDY_NAME}_{COLLIDER}',
    link=None,
    plot_contours=True,
    conf_mad=conf_mad,
    conf_collider=conf_collider,
    type_crossing="flathv",
    betx=1.1,
    bety=1.1,
    Nb=True,
    green_contour=6.,
    extended_diagonal=False,
    vmin=4.,
    vmax=8.0,
    CC = True,
)
